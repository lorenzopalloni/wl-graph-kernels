# %% [markdown]
# ## 'Named Rock Unit'

# %%
import rdflib
from collections import Counter

# %%
g = rdflib.Graph().parse('./data/Lexicon_NamedRockUnit.nt', format='nt')

# %%
hasLithogenesis_triples = [(s, p, o) for (s, p, o) in g if str(p).endswith('hasLithogenesis')]
labels = {
    label for (label, count) in Counter(o for (s, p, o) in hasLithogenesis_triples).most_common(2)
}
labels
# Out:
# {rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/FLUV'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI')}

# %%
instances_triples = {(s, p, o) for (s, p, o) in g if str(p).endswith('hasLithogenesis') and o in labels}
instances = [s for (s, _, _) in instances_triples]
print('number of instances: ', len(instances))
assert len(set(instances)) == len(instances)
# Out:
# number of instances:  146

# %%
# creating a subset of the graph
sub_instances = instances[:3]
sub_g = [(s, p, o) for (s, p, o) in g if s in sub_instances]
sub_instances_triples = [(s, p, o) for (s, p, o) in sub_g]
sub_instances_triples
# Out:
# [(rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('Red Lion Till Member', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasRevisionNumber'),
#   rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#inScheme'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_Z')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#   rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasUpperBoundaryDefinition'),
#   rdflib.term.Literal('At surface.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSourceInfo'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_52631')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_SANDU')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasYoungestAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasShapeType'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasUpperBoundaryDefinition'),
#   rdflib.term.Literal('The Holkham Till Member is at surface or is locally overlain unconformably by sand and gravel of the Ringstead Sand and Gravel Member, by Head, and silt and clay of the British Coastal Deposits Group. The junction with the overlying deposits is unconformable and because of the change in lithology is easily discernable.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#inScheme'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSourceInfo'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_51453')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasYoungestAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#prefLabel'),
#   rdflib.term.Literal('Red Lion Till Member', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasPredominantAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_CLAY')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasOldestAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasRockUnitRank'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/M')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasUnitClass'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Class/LS')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSpatialScopeOfDefinition'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/NotApplicable')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLowerBoundaryDefinition'),
#   rdflib.term.Literal('Rests with sharp base on bedrock geology, eg London Clay.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasFormality'),
#   rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasFormality'),
#   rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyDescription'),
#   rdflib.term.Literal('Sand and gravel, locally with lenses of silt, clay or peat. [Generic description].', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/hasCurrentStatus'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSpatialScopeOfDefinition'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/NotApplicable')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasThicknessDescription'),
#   rdflib.term.Literal('Up to 10m', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLowerBoundaryDefinition'),
#   rdflib.term.Literal('The Holkham Till Member is unconformably on older deposits. Locally it overlies gravel of an Ipswichian raised beach in the Hunstanton and Morston areas. Elsewhere it overlies a variety of Lower to Upper Cretaceous formations. There is an abrupt and very obvious lithological change across the boundary from the underlying arenaceous material or chalk, to the clay-silt dominated lithology of the till.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/hasCurrentStatus'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('Holkham Till Member', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#inScheme'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLateralEquivalent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___st__422')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('Taplow Gravel Formation', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#isDefinedBy'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSourceInfo'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51205')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasDefinitionStatus'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/FULL')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#   rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasTheme'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithogenesis'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasOldestAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/isOnshoreOffshore'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#prefLabel'),
#   rdflib.term.Literal('Taplow Gravel Formation', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/isOnshoreOffshore'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#altLabel'),
#   rdflib.term.Literal('HOTI', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSourceInfo'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_50918')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasStratotype'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40611')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#broader'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOLD')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasFormality'),
#   rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSpatialScopeOfDefinition'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/GENRAL')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#prefLabel'),
#   rdflib.term.Literal('Holkham Till Member', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithogenesis'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyDescription'),
#   rdflib.term.Literal('The Holkham Till Member is a dull reddish brown sandy clayey diamicton, which contains chalk and flint clasts together with Carboniferous and Triassic material and a variety of igneous and metamorphic rocks.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#altLabel'),
#   rdflib.term.Literal('RLTI', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasGeographicalDistribution'),
#   rdflib.term.Literal('Along much of the northern coastal area of Norfolk from west of Hunstanton to Morston.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasGeographicalDistribution'),
#   rdflib.term.Literal('Thames Valley and associated tributaries.', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSourceInfo'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51990')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://purl.org/dc/terms/identifier'),
#   rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasOldestAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasPredominantAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasShapeType'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasDefinitionStatus'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/INDEX')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasPredominantAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasTheme'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#altLabel'),
#   rdflib.term.Literal('TPGR', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasDefinitionStatus'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/FULL')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasObsoleteEquivalent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___mn__2061')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/isOnshoreOffshore'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_GRAV')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#broader'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/__NE__')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasRockUnitRank'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/M')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasSourceInfo'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51926')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasThicknessDescription'),
#   rdflib.term.Literal('Average 5m, locally to 9m', lang='en')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasShapeType'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_DMTN')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/hasCurrentStatus'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithogenesis'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/FLUV')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasStratotype'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40612')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasRevisionNumber'),
#   rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasUnitClass'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Class/LS')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasYoungestAge'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#isDefinedBy'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_C')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasRockUnitRank'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/F')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#broader'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOLD')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasObsoleteEquivalent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/TPGR___mn__4102')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasStratotype'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/39198')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#isDefinedBy'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasTheme'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasLithologyComponent'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/RLTI_DMTN')),
#  (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#   rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/hasRevisionNumber'),
#   rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))]

# %%
from collections import defaultdict
from pprint import pprint

V = []
E = []
depth = 2
labels = defaultdict()
vMap = []
eMap = []
search_front = []
V_sub = defaultdict()
E_sub = defaultdict()


# 1. Initialization
for i in sub_instances:
    V.append(i)
    labels[(i, depth)] = ''
    vMap.append(i)
# 2. Subgraph Extraction
for i in sub_instances:
    search_front.append(i)
    for i in range(d - 1, 0, -1):
        new_search_front = []
        for r in search_front:
            triples = [(s, p, o) for (s, p, o) in sub_g if s == r]
            for (s, p, o) in triples:
                new_search_front.append(o)
                if o not in vMap:
                    V.append(o)
                    vMap.append(o)
                labels[(o), depth] = o
                if o not in V_sub.keys():
                    V_sub[o] = depth
                if (s, p, o) not in eMap:
                    E.append((s, p, o))
                    eMap.append((s, p, o))
                labels[(s, p, o)] = p
                if (s, p, o) not in E_sub:
                    E_sub[(s, p, o)] = depth
        search_front = new_search_front
pprint(V)
pprint(labels)
pprint(vMap)
# Out:
# [rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#  rdflib.term.Literal('Red Lion Till Member', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/M'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/NotApplicable'),
#  rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOLD'),
#  rdflib.term.Literal('RLTI', lang='en'),
#  rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept'),
#  rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/INDEX'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/RLTI_DMTN'),
#  rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR', lang='en'),
#  rdflib.term.Literal('At surface.', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_52631'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_SANDU'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_51453'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_CLAY'),
#  rdflib.term.Literal('Rests with sharp base on bedrock geology, eg London Clay.', lang='en'),
#  rdflib.term.Literal('Sand and gravel, locally with lenses of silt, clay or peat. [Generic description].', lang='en'),
#  rdflib.term.Literal('Taplow Gravel Formation', lang='en'),
#  rdflib.term.Literal('Thames Valley and associated tributaries.', lang='en'),
#  rdflib.term.Literal('TPGR', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/FULL'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_GRAV'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/__NE__'),
#  rdflib.term.Literal('Average 5m, locally to 9m', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/FLUV'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Class/LS'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/F'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/TPGR___mn__4102'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/39198'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_Z'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD'),
#  rdflib.term.Literal('The Holkham Till Member is at surface or is locally overlain unconformably by sand and gravel of the Ringstead Sand and Gravel Member, by Head, and silt and clay of the British Coastal Deposits Group. The junction with the overlying deposits is unconformable and because of the change in lithology is easily discernable.', lang='en'),
#  rdflib.term.Literal('Up to 10m', lang='en'),
#  rdflib.term.Literal('The Holkham Till Member is unconformably on older deposits. Locally it overlies gravel of an Ipswichian raised beach in the Hunstanton and Morston areas. Elsewhere it overlies a variety of Lower to Upper Cretaceous formations. There is an abrupt and very obvious lithological change across the boundary from the underlying arenaceous material or chalk, to the clay-silt dominated lithology of the till.', lang='en'),
#  rdflib.term.Literal('Holkham Till Member', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___st__422'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51205'),
#  rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI', lang='en'),
#  rdflib.term.Literal('HOTI', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_50918'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40611'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/GENRAL'),
#  rdflib.term.Literal('The Holkham Till Member is a dull reddish brown sandy clayey diamicton, which contains chalk and flint clasts together with Carboniferous and Triassic material and a variety of igneous and metamorphic rocks.', lang='en'),
#  rdflib.term.Literal('Along much of the northern coastal area of Norfolk from west of Hunstanton to Morston.', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51990'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___mn__2061'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51926'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_DMTN'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40612'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_C'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))]
# defaultdict(None,
#             {(rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Class/LS'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Class/LS'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/FULL'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/FULL'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/INDEX'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/INDEX'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___mn__2061'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___mn__2061'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___st__422'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___st__422'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/TPGR___mn__4102'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/TPGR___mn__4102'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/FLUV'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/FLUV'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_C'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_C'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_DMTN'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_DMTN'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_Z'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_Z'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/RLTI_DMTN'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/RLTI_DMTN'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_CLAY'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_CLAY'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_GRAV'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_GRAV'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_SANDU'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_SANDU'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOLD'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOLD'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'), 2): '',
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'), 2): '',
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'), 2): '',
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/__NE__'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/__NE__'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/F'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/F'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/M'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/M'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_50918'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_50918'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51205'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51205'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51926'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51926'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51990'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51990'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_51453'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_51453'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_52631'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_52631'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/GENRAL'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/GENRAL'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/NotApplicable'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/NotApplicable'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/39198'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/39198'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40611'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40611'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40612'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40612'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT'),
#              (rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit'), 2): rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit'),
#              (rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept'), 2): rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept'),
#              (rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), 2): rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),
#              (rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), 2): rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),
#              (rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), 2): rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#              (rdflib.term.Literal('Along much of the northern coastal area of Norfolk from west of Hunstanton to Morston.', lang='en'), 2): rdflib.term.Literal('Along much of the northern coastal area of Norfolk from west of Hunstanton to Morston.', lang='en'),
#              (rdflib.term.Literal('At surface.', lang='en'), 2): rdflib.term.Literal('At surface.', lang='en'),
#              (rdflib.term.Literal('Average 5m, locally to 9m', lang='en'), 2): rdflib.term.Literal('Average 5m, locally to 9m', lang='en'),
#              (rdflib.term.Literal('HOTI', lang='en'), 2): rdflib.term.Literal('HOTI', lang='en'),
#              (rdflib.term.Literal('Holkham Till Member', lang='en'), 2): rdflib.term.Literal('Holkham Till Member', lang='en'),
#              (rdflib.term.Literal('RLTI', lang='en'), 2): rdflib.term.Literal('RLTI', lang='en'),
#              (rdflib.term.Literal('Red Lion Till Member', lang='en'), 2): rdflib.term.Literal('Red Lion Till Member', lang='en'),
#              (rdflib.term.Literal('Rests with sharp base on bedrock geology, eg London Clay.', lang='en'), 2): rdflib.term.Literal('Rests with sharp base on bedrock geology, eg London Clay.', lang='en'),
#              (rdflib.term.Literal('Sand and gravel, locally with lenses of silt, clay or peat. [Generic description].', lang='en'), 2): rdflib.term.Literal('Sand and gravel, locally with lenses of silt, clay or peat. [Generic description].', lang='en'),
#              (rdflib.term.Literal('TPGR', lang='en'), 2): rdflib.term.Literal('TPGR', lang='en'),
#              (rdflib.term.Literal('Taplow Gravel Formation', lang='en'), 2): rdflib.term.Literal('Taplow Gravel Formation', lang='en'),
#              (rdflib.term.Literal('Thames Valley and associated tributaries.', lang='en'), 2): rdflib.term.Literal('Thames Valley and associated tributaries.', lang='en'),
#              (rdflib.term.Literal('The Holkham Till Member is a dull reddish brown sandy clayey diamicton, which contains chalk and flint clasts together with Carboniferous and Triassic material and a variety of igneous and metamorphic rocks.', lang='en'), 2): rdflib.term.Literal('The Holkham Till Member is a dull reddish brown sandy clayey diamicton, which contains chalk and flint clasts together with Carboniferous and Triassic material and a variety of igneous and metamorphic rocks.', lang='en'),
#              (rdflib.term.Literal('The Holkham Till Member is at surface or is locally overlain unconformably by sand and gravel of the Ringstead Sand and Gravel Member, by Head, and silt and clay of the British Coastal Deposits Group. The junction with the overlying deposits is unconformable and because of the change in lithology is easily discernable.', lang='en'), 2): rdflib.term.Literal('The Holkham Till Member is at surface or is locally overlain unconformably by sand and gravel of the Ringstead Sand and Gravel Member, by Head, and silt and clay of the British Coastal Deposits Group. The junction with the overlying deposits is unconformable and because of the change in lithology is easily discernable.', lang='en'),
#              (rdflib.term.Literal('The Holkham Till Member is unconformably on older deposits. Locally it overlies gravel of an Ipswichian raised beach in the Hunstanton and Morston areas. Elsewhere it overlies a variety of Lower to Upper Cretaceous formations. There is an abrupt and very obvious lithological change across the boundary from the underlying arenaceous material or chalk, to the clay-silt dominated lithology of the till.', lang='en'), 2): rdflib.term.Literal('The Holkham Till Member is unconformably on older deposits. Locally it overlies gravel of an Ipswichian raised beach in the Hunstanton and Morston areas. Elsewhere it overlies a variety of Lower to Upper Cretaceous formations. There is an abrupt and very obvious lithological change across the boundary from the underlying arenaceous material or chalk, to the clay-silt dominated lithology of the till.', lang='en'),
#              (rdflib.term.Literal('Up to 10m', lang='en'), 2): rdflib.term.Literal('Up to 10m', lang='en'),
#              (rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI', lang='en'), 2): rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI', lang='en'),
#              (rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI', lang='en'), 2): rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI', lang='en'),
#              (rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR', lang='en'), 2): rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR', lang='en')})
# [rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI'),
#  rdflib.term.Literal('Red Lion Till Member', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/ref/Lexicon/NamedRockUnit'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/Q2'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/M'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/NotApplicable'),
#  rdflib.term.Literal('FORMAL', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/ref/CurrentStatus/CURRENT'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Theme/SPRFCL'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/GLACI'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOLD'),
#  rdflib.term.Literal('RLTI', lang='en'),
#  rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#Concept'),
#  rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/RLTI', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/ShapeType/NotEntered'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/INDEX'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/onshoreOffshore/ONSHORE'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/RLTI_DMTN'),
#  rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/TPGR', lang='en'),
#  rdflib.term.Literal('At surface.', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_52631'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_SANDU'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/TPGR_51453'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QO'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_CLAY'),
#  rdflib.term.Literal('Rests with sharp base on bedrock geology, eg London Clay.', lang='en'),
#  rdflib.term.Literal('Sand and gravel, locally with lenses of silt, clay or peat. [Generic description].', lang='en'),
#  rdflib.term.Literal('Taplow Gravel Formation', lang='en'),
#  rdflib.term.Literal('Thames Valley and associated tributaries.', lang='en'),
#  rdflib.term.Literal('TPGR', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/DefinitionStatus/FULL'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/TPGR_GRAV'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/__NE__'),
#  rdflib.term.Literal('Average 5m, locally to 9m', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithogeneticType/FLUV'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Class/LS'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/RockUnitRank/F'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/TPGR___mn__4102'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/39198'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_Z'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Geochronology/Division/QD'),
#  rdflib.term.Literal('The Holkham Till Member is at surface or is locally overlain unconformably by sand and gravel of the Ringstead Sand and Gravel Member, by Head, and silt and clay of the British Coastal Deposits Group. The junction with the overlying deposits is unconformable and because of the change in lithology is easily discernable.', lang='en'),
#  rdflib.term.Literal('Up to 10m', lang='en'),
#  rdflib.term.Literal('The Holkham Till Member is unconformably on older deposits. Locally it overlies gravel of an Ipswichian raised beach in the Hunstanton and Morston areas. Elsewhere it overlies a variety of Lower to Upper Cretaceous formations. There is an abrupt and very obvious lithological change across the boundary from the underlying arenaceous material or chalk, to the clay-silt dominated lithology of the till.', lang='en'),
#  rdflib.term.Literal('Holkham Till Member', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___st__422'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51205'),
#  rdflib.term.Literal('http://data.bgs.ac.uk/id/Lexicon/NamedRockUnit/HOTI', lang='en'),
#  rdflib.term.Literal('HOTI', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_50918'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40611'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SpatialScope/GENRAL'),
#  rdflib.term.Literal('The Holkham Till Member is a dull reddish brown sandy clayey diamicton, which contains chalk and flint clasts together with Carboniferous and Triassic material and a variety of igneous and metamorphic rocks.', lang='en'),
#  rdflib.term.Literal('Along much of the northern coastal area of Norfolk from west of Hunstanton to Morston.', lang='en'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51990'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/EquivalentName/HOTI___mn__2061'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/SourceInfo/HOTI_51926'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_DMTN'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/Stratotype/40612'),
#  rdflib.term.URIRef('http://data.bgs.ac.uk/id/Lexicon/LithologyComponent/HOTI_C'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))]
